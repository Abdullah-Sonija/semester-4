# %% [markdown]
# q1

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# q2

# %%
a=2
b=3.3
print(f"Data type of a: {type(a)}")
print(f"Data type of b: {type(b)}")
# Out:
# Data type of a: <class 'int'>
# Data type of b: <class 'float'>

# %% [markdown]
# q3

# %%
name = input("enter your name: ")
print(name)
# Out:
# Abdullah Sonija

# %% [markdown]
# q4

# %%
t = "Hello World!"
print(t[2:5])
print(t*2)
# Out:
# llo
# Hello World!Hello World!

# %% [markdown]
# q5

# %%
list1 = ["physics","chemistry",1997,2000]
list1[2]=2001
print(list1)
del(list1[2])
print(list1)
# Out:
# ['physics', 'chemistry', 2001, 2000]
# ['physics', 'chemistry', 2000]

# %% [markdown]
# q6

# %%
tuple = ("abcd",768,2.23)
list = ["abcd",768,2.23]

# %%
list[0]=1000

# %%
tuple[0]=1000
# Tuples are immutable so that they can not be reassigned (TypeError)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 tuple[0]=1000
#       2 # Tuples are immutable so that they can not be reassigned (TypeError)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# q7

# %%
tinydict = {"name":"Abdullah","code":556,"dept":"Ai"}
print(tinydict.keys())
# Out:
# dict_keys(['name', 'code', 'dept'])

# %% [markdown]
# q8

# %%
amount = 6000

if amount < 1000:
    discount = amount * 0.05
elif amount < 5000:
    discount = amount * 0.10
else:
    discount = amount * 0.15

net_payable = amount - discount
print("Net payable:", net_payable)
# Out:
# Net payable: 5100.0

# %% [markdown]
# q9

# %%
count = 0
while count < 9:
    print(count)
    count+=1
print("Good Bye")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# Good Bye

# %% [markdown]
# q10

# %%
def details(*numbers):
    for num in numbers:
        print(num)

details(1,2,3)
# Out:
# 1
# 2
# 3
